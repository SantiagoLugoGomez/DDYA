# %% [markdown]
# ## Problema - Organización y búsqueda de productos en una tienda
#
# **Instrucción:** completa esta plantilla con tu diseño y desarrollo. Evita incluir soluciones generadas automáticamente.

# %%
# @title Ingrese datos
nombre_estudiante = "Juan Pablo Leon Davila" # @param {"type":"string"}
carnet = 1000114216 # @param {"type":"integer"}

# %% [markdown]
# ## 1) Descripción del problema **[1 pts]**
#
# Una tienda maneja una lista con los códigos numéricos de sus productos. Como los productos se registran a medida que llegan, los códigos inicialmente se encuentran desordenados.
#
# El encargado necesita desarrollar un programa que permita:
#
# * Registrar una cantidad n de productos.
# * Ordenar sus códigos utilizando Merge Sort.
# * Buscar un código específico utilizando Búsqueda Binaria.

# %% [markdown]
# ## 2) Requerimientos **[2 pts]**
#
# **Requerimientos Funcionales**
#
# 1. El sistema debe permitir ingresar la cantidad `n` de productos que se van a registrar.
# 2. El sistema debe permitir ingresar un código numérico para cada producto.
# 3. El sistema debe mostrar la lista original de códigos en el orden en que fueron registrados.
# 4. El sistema debe ordenar los códigos utilizando el algoritmo **Merge Sort**.
# 5. El sistema debe mostrar la lista de códigos después de ser ordenada.
# 6. El sistema debe permitir ingresar un código que se desea buscar.
# 7. El sistema debe realizar la búsqueda utilizando **Búsqueda Binaria** sobre la lista ordenada.
# 8. El sistema debe informar si el código buscado fue encontrado o si no está registrado.
#
# **Requerimientos No Funcionales**
#
# 1. El programa debe estar implementado en Python.
# 2. La lista debe quedar ordenada antes de realizar la búsqueda binaria.
# 3. El programa debe ser claro, legible y estar dividido en funciones.
# 4. La solución debe utilizar Merge Sort para ordenar y Búsqueda Binaria para buscar, sin reemplazarlos por funciones de ordenamiento o búsqueda de Python.
# 5. El programa debe producir resultados correctos para diferentes cantidades de productos y códigos.

# %% [markdown]
# ## 3) Historias de usuario **[2 pts]**
#
# ### Historia de usuario 1 — Registrar productos
# **Como** encargado de la tienda, **quiero** registrar la cantidad y los códigos de los productos, **para** tener almacenada la información que posteriormente será organizada y consultada.
#
# **Criterios de aceptación:**
# - Se debe solicitar la cantidad de productos `n`.
# - Se debe solicitar un código numérico por cada producto.
# - Los códigos deben almacenarse en una lista.
# - Al finalizar el registro, se debe mostrar la lista original.
#
# ### Historia de usuario 2 — Ordenar productos
# **Como** encargado de la tienda, **quiero** ordenar los códigos de los productos, **para** facilitar su consulta y permitir realizar una búsqueda binaria.
#
# **Criterios de aceptación:**
# - La lista debe ordenarse utilizando Merge Sort.
# - El resultado debe quedar organizado de menor a mayor.
# - Se debe mostrar la lista ordenada antes de realizar la búsqueda.
#
# ### Historia de usuario 3 — Buscar un producto
# **Como** encargado de la tienda, **quiero** buscar un código específico, **para** saber rápidamente si el producto está registrado.
#
# **Criterios de aceptación:**
# - Se debe solicitar el código que se desea buscar.
# - La búsqueda debe realizarse sobre la lista previamente ordenada.
# - Se debe utilizar Búsqueda Binaria.
# - El sistema debe indicar claramente si el código fue encontrado o no.
#
# ### Historia de usuario 4 — Consultar el resultado
# **Como** encargado de la tienda, **quiero** visualizar el resultado de la búsqueda, **para** conocer inmediatamente si el producto solicitado existe en el registro.
#
# **Criterios de aceptación:**
# - Si el código existe, se debe informar que fue encontrado.
# - Si el código no existe, se debe informar que no está registrado.

# %% [markdown]
# ## 4) Diagramas de flujo **[5 pts]**
# Incluye el diagrama que muestre el proceso general
#
# ![image.png]()![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 5) Diagramas de secuencia **[5 pts]**
# Incluye el diagrama que muestre el proceso general
#
# Adjunta imagen y descríbelo claramente.![Captura de pantalla 2026-08-13 172104.png](data:image/png;base64,...)

# %% [markdown]
# ## 6) Diagramas de casos de uso **[5 pts]**
# Incluye el diagrama que muestre el proceso general
#
# Adjunta imagen y descríbelo claramente.

# %% [markdown]
# ## 7) Análisis de complejidad **[15 pts]**
#
# ### Justificación
#
# El programa utiliza dos algoritmos principales. Primero, **Merge Sort** divide la lista en dos partes de manera recursiva y después mezcla las partes ordenadas. En cada nivel de la recursión se procesan aproximadamente `n` elementos y existen `log2(n)` niveles, por lo que su complejidad es `O(n log n)` tanto en el mejor como en el peor caso.
#
# Después de ordenar, se utiliza **Búsqueda Binaria**. En cada iteración se descarta aproximadamente la mitad de los elementos posibles. Por esto, en el peor caso se necesitan `log2(n)` comparaciones y su complejidad es `O(log n)`. En el mejor caso, el elemento buscado está justo en la posición central y solamente se necesita una comparación, por lo que es `O(1)`.
#
# ### Función T[n]
#
# Para Merge Sort, la recurrencia es:
#
# `T(n) = 2T(n/2) + O(n)`
#
# Al resolverla se obtiene:
#
# `T(n) = O(n log n)`
#
# Para Búsqueda Binaria:
#
# `T(n) = T(n/2) + O(1)`
#
# Por tanto:
#
# `T(n) = O(log n)`
#
# Si se considera el programa completo, primero se debe ordenar y después realizar la búsqueda. Entonces:
#
# `T(n) = O(n log n) + O(log n)`
#
# Como `n log n` crece más rápido que `log n`, la complejidad dominante del programa completo es:
#
# **T(n) = O(n log n)**
#
# ### Mejor y peor caso
#
# | Parte del programa | Mejor caso | Peor caso |
# |---|---|---|
# | Merge Sort | O(n log n) | O(n log n) |
# | Búsqueda Binaria | O(1) | O(log n) |
# | Programa completo | O(n log n) | O(n log n) |
#
# La diferencia entre el mejor y el peor caso del programa completo no cambia el orden de crecimiento porque Merge Sort domina el costo total. La Búsqueda Binaria sí cambia entre `O(1)` y `O(log n)`, pero ambas son menores que `O(n log n)`.
#
# ### Graficas.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 8) Código funcional **[15 pts]**
# Incluye tu implementación completa.
#
# No pegues código incompleto; debe ser ejecutable.

# %%
# Ejercicio: Organización y búsqueda de productos en una tienda


# Función para ordenar con Merge Sort
def merge_sort(lista):
    # Caso base: si la lista tiene 0 o 1 elemento, ya está "ordenada"
    if len(lista) <= 1:
        return lista

    # Dividimos la lista en dos mitades
    mitad = len(lista) // 2
    izquierda = lista[:mitad]
    derecha = lista[mitad:]

    # Ordenamos cada mitad por separado
    izquierda = merge_sort(izquierda)
    derecha = merge_sort(derecha)

    # Unimos las dos mitades ya ordenadas
    return mezclar(izquierda, derecha)


def mezclar(izq, der):
    resultado = []
    i = 0
    j = 0

    # Comparamos los elementos de ambas listas
    while i < len(izq) and j < len(der):
        if izq[i] < der[j]:
            resultado.append(izq[i])
            i = i + 1
        else:
            resultado.append(der[j])
            j = j + 1

    # Agregamos los elementos restantes de la izquierda
    while i < len(izq):
        resultado.append(izq[i])
        i = i + 1

    # Agregamos los elementos restantes de la derecha
    while j < len(der):
        resultado.append(der[j])
        j = j + 1

    return resultado


# Función para buscar con Búsqueda Binaria
def busqueda_binaria(lista, buscado):
    inicio = 0
    fin = len(lista) - 1

    while inicio <= fin:
        medio = (inicio + fin) // 2

        if lista[medio] == buscado:
            return True

        elif lista[medio] < buscado:
            inicio = medio + 1

        else:
            fin = medio - 1

    return False


# Programa principal

n = int(input("Ingrese la cantidad de productos: "))

codigos = []

for i in range(n):
    codigo = int(input(f"Ingrese el código del producto {i + 1}: "))
    codigos.append(codigo)

print("Lista original:", codigos)

codigos_ordenados = merge_sort(codigos)

print("Lista ordenada:", codigos_ordenados)

buscado = int(input("Ingrese el código que desea buscar: "))

if busqueda_binaria(codigos_ordenados, buscado):
    print(f"El producto con código {buscado} fue encontrado.")
else:
    print(f"El producto con código {buscado} no se encuentra registrado.")
# Out:
# Ingrese la cantidad de productos: 4
# Ingrese el código del producto 1: 3
# Ingrese el código del producto 2: 4
# Ingrese el código del producto 3: 112
# Ingrese el código del producto 4: 345
# Lista original: [3, 4, 112, 345]
# Lista ordenada: [3, 4, 112, 345]
#
# Ingrese el código que desea buscar: 4
# El producto con código 4 fue encontrado.
